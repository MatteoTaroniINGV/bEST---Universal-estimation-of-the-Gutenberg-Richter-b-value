# %% [markdown]
# ## Monte Carlo validation for Gutenberg-Richter b-value estimators

# %% [markdown]
# This notebook runs the validation workflow from `validation.py`.\nSet the parameters below, then run the last cell to execute the simulations and produce summary + plots.

# %%
from validation import run_validation

# %% [markdown]
# ### Parameters

# %%
NUM_SIM = 1000\nBVALUE_TRUE = 1.0\nNUM_EV = 10000\nMC = 1.5\nMAGN_BIN = 0.0      # 0.0, 0.1, 0.01\nDELTA_M = 0.1\nK = 5\nMETHOD = 4          # 1, 2, 3, or 4\nRANDOM_SEED = 42\nBOOTSTRAP_NUM = 200\nDMAX = 100

# %%
b_estimates, n_estimates, sigma_estimates = run_validation(\n    num_sim=NUM_SIM,\n    bvalue_true=BVALUE_TRUE,\n    num_ev=NUM_EV,\n    mc=MC,\n    magn_bin=MAGN_BIN,\n    delta_m=DELTA_M,\n    k=K,\n    method=METHOD,\n    random_seed=RANDOM_SEED,\n    bootstrap_num=BOOTSTRAP_NUM,\n    dmax=DMAX,\n)
